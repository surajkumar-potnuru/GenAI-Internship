# %% [markdown]
# <a href="https://colab.research.google.com/github/surajkumar-potnuru/GenAI-Internship/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Problem 1: Student Report Card
students = {"Rahul":91,"Ayesha":84,"Kiran":67,"Ali":45}
passed = 0
for student,marks in students.items():
  print(student,marks)
  if marks >= 40:
    print("Pass")
    passed += 1
  else:
    print("Fail")
print("No of students passed",passed)
# Out:
# Rahul 91
# Pass
# Ayesha 84
# Pass
# Kiran 67
# Pass
# Ali 45
# Pass
# No of students passed 4
